# %%
import json
import pandas as pd

# %%
with open('yelp_academic_dataset_user.json') as json_file:
    data = json_file.readlines()
    

data_json_user = "["+ ','.join(data) +"]"
user = pd.read_json(data_json_user)

with open('yelp_academic_dataset_business.json') as json_file:
    data = json_file.readlines()
    
data_json_business = "["+ ','.join(data) +"]"
business = pd.read_json(data_json_business)

with open('yelp_academic_dataset_tip.json') as json_file:
    data = json_file.readlines()
    
data_json_tip = "["+ ','.join(data) +"]"
tip = pd.read_json(data_json_tip)


with open('yelp_academic_dataset_checkin.json') as json_file:
    data = json_file.readlines()
    
data_json_checkin = "["+ ','.join(data) +"]"
checkin = pd.read_json(data_json_checkin)

with open('yelp_academic_dataset_review.json') as json_file:
    data = json_file.readlines()
    
data_json_reveiw = "["+ ','.join(data) +"]"
review = pd.read_json(data_json_reveiw)

# %%
user.loc[:,["fans","average_stars","review_count"]].describe()
# Out:
#                 fans  average_stars   review_count
# count  686556.000000  686556.000000  686556.000000
# mean        1.290100       3.746704      25.757102
# std        11.501621       1.086832      83.755973
# min         0.000000       0.000000       0.000000
# 25%         0.000000       3.230000       2.000000
# 50%         0.000000       3.920000       5.000000
# 75%         0.000000       4.600000      17.000000
# max      3549.000000       5.000000   10897.000000

# %%
business.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85901 entries, 0 to 85900
# Data columns (total 15 columns):
# attributes       85901 non-null object
# business_id      85901 non-null object
# categories       85901 non-null object
# city             85901 non-null object
# full_address     85901 non-null object
# hours            85901 non-null object
# latitude         85901 non-null float64
# longitude        85901 non-null float64
# name             85901 non-null object
# neighborhoods    85901 non-null object
# open             85901 non-null bool
# review_count     85901 non-null int64
# stars            85901 non-null float64
# state            85901 non-null object
# type             85901 non-null object
# dtypes: bool(1), float64(3), int64(1), object(10)
# memory usage: 9.9+ MB

# %%
business.city.value_counts()
# Out:
# Las Vegas           19328
# Phoenix             11852
# Charlotte            5695
# Scottsdale           5638
# Montréal             4371
# Mesa                 3638
# Pittsburgh           3628
# Edinburgh            3360
# Henderson            3145
# Tempe                3043
# Chandler             2702
# Madison              2278
# Glendale             2048
# Gilbert              1941
# Peoria               1081
# North Las Vegas       952
# Karlsruhe             906
# Surprise              681
# Goodyear              507
# Champaign             505
# Avondale              427
# Matthews              399
# Queen Creek           383
# Waterloo              297
# Fort Mill             287
# Urbana                286
# Cave Creek            266
# Laval                 222
# Middleton             222
# Pineville             210
#                     ...
# Lachenaie               1
# Sunnyslope              1
# Maricopa AZ             1
# Estrella Village        1
# ...

# %%
business
# Out:
#                                               attributes  \
# 0      {'Price Range': 1, 'Good For': {'dinner': Fals...
# 1      {'Happy Hour': True, 'Price Range': 1, 'Outdoo...
# 2                                {'Good for Kids': True}
# 3      {'Caters': True, 'Coat Check': False, 'Has TV'...
# 4      {'Good for Kids': True, 'Takes Reservations': ...
# 5      {'Caters': False, 'Coat Check': False, 'Has TV...
# 6                         {'Accepts Credit Cards': True}
# 7                                {'Good for Kids': True}
# 8                                                     {}
# 9                                                     {}
# 10                                     {'Wi-Fi': 'free'}
# 11                                                    {}
# 12     {'Price Range': 1, 'Wheelchair Accessible': Tr...
# 13     {'Take-out': True, 'Price Range': 1, 'Wheelcha...
# 14                                                    {}
# ...

# %%
business.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85901 entries, 0 to 85900
# Data columns (total 15 columns):
# attributes       85901 non-null object
# business_id      85901 non-null object
# categories       85901 non-null object
# city             85901 non-null object
# full_address     85901 non-null object
# hours            85901 non-null object
# latitude         85901 non-null float64
# longitude        85901 non-null float64
# name             85901 non-null object
# neighborhoods    85901 non-null object
# open             85901 non-null bool
# review_count     85901 non-null int64
# stars            85901 non-null float64
# state            85901 non-null object
# type             85901 non-null object
# dtypes: bool(1), float64(3), int64(1), object(10)
# memory usage: 9.9+ MB

# %%
business[business.city=="Las Vegas"].review_count.describe()
# Out:
# count    19328.000000
# mean        59.174669
# std        195.947228
# min          3.000000
# 25%          5.000000
# 50%         12.000000
# 75%         38.000000
# max       6200.000000
# Name: review_count, dtype: float64

# %%
business.isnull().sum()
# Out:
# attributes       0
# business_id      0
# categories       0
# city             0
# full_address     0
# hours            0
# latitude         0
# longitude        0
# name             0
# neighborhoods    0
# open             0
# review_count     0
# stars            0
# state            0
# type             0
# dtype: int64
